# %%
import pandas as pd

# %%
df = pd.read_csv("09th_Links.csv")

# %%
df
# Out:
#                                                  Links
# 0    https://nvidia.wd5.myworkdayjobs.com/en-US/NVI...
# 1    https://nvidia.wd5.myworkdayjobs.com/en-US/NVI...
# 2    https://nvidia.wd5.myworkdayjobs.com/en-US/NVI...
# 3    https://nvidia.wd5.myworkdayjobs.com/en-US/NVI...
# 4    https://nvidia.wd5.myworkdayjobs.com/en-US/NVI...
# ..                                                 ...
# 484  https://nvidia.wd5.myworkdayjobs.com/en-US/NVI...
# 485  https://nvidia.wd5.myworkdayjobs.com/en-US/NVI...
# 486  https://nvidia.wd5.myworkdayjobs.com/en-US/NVI...
# 487  https://nvidia.wd5.myworkdayjobs.com/en-US/NVI...
# 488  https://nvidia.wd5.myworkdayjobs.com/en-US/NVI...
#
# [489 rows x 1 columns]

# %%
x = df[['Links']]

# %%
x.head()
# Out:
#                                                Links
# 0  https://nvidia.wd5.myworkdayjobs.com/en-US/NVI...
# 1  https://nvidia.wd5.myworkdayjobs.com/en-US/NVI...
# 2  https://nvidia.wd5.myworkdayjobs.com/en-US/NVI...
# 3  https://nvidia.wd5.myworkdayjobs.com/en-US/NVI...
# 4  https://nvidia.wd5.myworkdayjobs.com/en-US/NVI...

# %%
y = x['Links'].str.split("\n")

# %%
kill = []

# %%
item1=[]

# %%
for i in y:
    item1.append(i[1])
    for j in i:
        if j == "Apply":
            break
        else:
            item=j
            kill.append(item)
    kill.append("NaN")

# %%
for count,entry in enumerate (kill,0):
    if entry in item1:
        kill[count]="Hello"
    else:
        pass

# %%
kill
# Out:
# ['https://nvidia.wd5.myworkdayjobs.com/en-US/NVIDIAExternalCareerSite/job/China-Beijing/Senior-System-Software-Engineer_JR1941341',
#  'Hello',
#  'China, Beijing',
#  'China, Shanghai',
#  'NaN',
#  'https://nvidia.wd5.myworkdayjobs.com/en-US/NVIDIAExternalCareerSite/job/US-CA-Santa-Clara/Senior-Network-Engineer--Cloud-Infrastructure---GPU_JR1940913',
#  'Hello',
#  'US, CA, Santa Clara',
#  'US, TX, Remote',
#  'US, CO, Remote',
#  'US, TN, Remote',
#  'US, CA, Remote',
#  'US, MA, Chelmsford',
#  'US, VA, Remote',
#  'US, AZ, Remote',
#  'NaN',
#  'https://nvidia.wd5.myworkdayjobs.com/en-US/NVIDIAExternalCareerSite/job/Israel-Yokneam/Physical-Design-CAD-Engineer_JR1943755',
#  'Hello',
#  'Israel, Yokneam',
#  'Israel, Tel Aviv-Yafo',
#  'NaN',
#  'https://nvidia.wd5.myworkdayjobs.com/en-US/NVIDIAExternalCareerSite/job/US-CA-Sunnyvale/Senior-Security-Research-Architect--Confidential-Computing_JR1943195',
#  'Hello',
#  'US, CA, Sunnyvale',
#  'US, CA, Remote',
#  'NaN',
# ...

# %%
y.to_csv("splited1.csv")

# %%
df = pd.DataFrame(kill)

# %%
df.to_csv("09thjuly_Extract.csv")

# %%
df
# Out:
#                                                       0
# 0     https://nvidia.wd5.myworkdayjobs.com/en-US/NVI...
# 1                                                 Hello
# 2                                        China, Beijing
# 3                                       China, Shanghai
# 4                                                   NaN
# ...                                                 ...
# 2963  https://nvidia.wd5.myworkdayjobs.com/en-US/NVI...
# 2964                                              Hello
# 2965                                    Canada, Toronto
# 2966                                     Canada, Remote
# 2967                                                NaN
#
# [2968 rows x 1 columns]
